# %% [markdown]
# # First I need to start with an article dictionary

# %%
from testdataextractor.testdataextractor.extractor import Extractor
ext = Extractor('../test_data/1957284403.ofs.gold.xml')
article = ext.extract(verbose=True)
# Out:
# 50  comments parsed.
# 190  sentences parsed.
# 140  links parsed.

# %% [markdown]
# # I then need to put the data in a format that I can query
# Maybe a way to do this is via pandas?
# I want it to look like so:
# <table>
# <tr>
#     <td>sentence</td>
#     <td>comment</td>
#     <td>links</td>
# </tr>
# <tr>
#     <td>
#         sentence id
#     </td>
#     <td>
#         comment id, if it is from a comment
#     </td>
#     <td>
#         list of sentences its linked to
#     </td>
# </tr>
# </table>

# %%
import pandas as pd

frame_art = pd.DataFrame.from_dict(article['sentences'], orient='index')

# %%
frame_art
# Out:
#      comment                                               text  \
# s0       NaN  BT and Vodafone among telecoms companies passi...
# s1       NaN  Some of the world 's leading telecoms firms , ...
# s10      NaN  It gives top secret codenames for each firm , ...
# s100     c17        Best way to keep your information secure ?
# s101     c17                                    Use Vodafone .
# s102     c17           You wo n't be in contact with anybody .
# s103     c18                     [Snapshackle ] Agreed , 4G? ?
# s104     c18     3G would be nice , or even a fucking signal .
# s105     c19  [ OurPlanet ] That really made me laugh in a s...
# s106     c19  Thanks VaughnParadisThe best antidote to this ...
# s107     c19            Fear only feeds these imbeciles egos .
# s108     c20  [ Malkatrinho] that 's a lovely shade of green .
# s109     c21  [jonbryce ] This is the former Cable & Wireles...
# s11      NaN  The other firms include Global Crossing ( " Pi...
# s110     c21  Lots of ISPs use them for their transatlantic ...
# s111     c21  Those that do n't use one of the other ones li...
# s112     c21                 Level 3 is probably the biggest .
# s113     c22  [IronCurtain ] The Governments and the Corpora...
# s114     c22                                       cui bonno ?
# s115     c22                                             you ?
# s116     c22                                              me ?
# s117     c22                                         Freedom ?
# s118     c22                                         Liberty ?
# s119     c22                                      not likely .
# s12      NaN  The companies refused to comment on any specif...
# s120     c23  [enfrance ] If apathy is the order of the day ...
# s121     c23                                 Nah , I despair .
# s122     c23  And the likelyhood of anyone boycotting either...
# s123     c23               How about a petition of some sort ?
# s124     c23  Its late and I 'm too tired and hot to think o...
# ...      ...                                                ...
# s72       c9  We need a revolution , and we need it now , to...
# s73      c10  [dennis79] All of this is certainly not done t...
# s74      c10     Spying upon politics , economics , NGOs etc .
# s75      c10  I 'm also pretty confident that a number of in...
# s76      c10  States have always set up people , used people...
# s77      c10  All this is far easier when in the possession ...
# s78      c11             [SpecialRX] I suspect you 're right .
# s79      c11                          Have a recommend on me .
# s8       NaN  The paper said it had seen a copy of an intern...
# s80      c12  [ Malkatrinho] It has nothing to do with &quot...
# s81      c12  It 's about keeping an eye on the general popu...
# s82      c13  [timetorememberagain ] A spokeswoman for Veriz...
# s83      c13  Verizon also complies with the law in every co...
# s84      c13  It sounds like they 're doing everything just ...
# s85      c13  So the government demands access to my ( and e...
# s86      c13  Sheer doublespeak and deception of the highest...
# s87      c13                           Recall Parliament now !
# s88      c13                                 Demonstrate now !
# s89      c14  [AGrumpyGit ] Democracy does indeed work that ...
# s9       NaN  The document identified for the first time whi...
# s90      c15  [timetorememberagain ] It should have been deb...
# s91      c15                                        Quite so .
# s92      c15  Those among us who might previously have argue...
# s93      c15  With luck we might even stage mass demonstrati...
# s94      c15                                        Organise !
# s95      c15                                          Resist !
# s96      c16  [SamSSSS] I do n't see why the existence of wa...
# s97      c16       It should have been debated in parliament .
# s98      c16  If the majority were in favour , the access wo...
# s99      c17  [VaughnParadis ] I 'd be concerned about Vodaf...
#
#                                                   links
# s0    [s66, s101, s82, s162, s118, s114, s113, s160,...
# s1                                                  NaN
# s10                                               [s57]
# s100                                   [s28, s167, s49]
# s101                                      [s0, s47, s0]
# s102                                        [s47, s115]
# s103                                              [s99]
# s104                                                NaN
# s105                                                NaN
# s106                                              [s56]
# s107                                              [s99]
# s108                                                NaN
# s109                                         [s99, s99]
# s11                                                 NaN
# s110                                                NaN
# s111                                  [s99, s165, s140]
# s112                                                NaN
# s113                                          [s0, s16]
# s114                                               [s0]
# s115                                             [s102]
# s116                                                NaN
# s117                                                NaN
# s118                                               [s0]
# s119               [s131, s133, s140, s127, s126, s129]
# s12                                                 NaN
# s120                                              [s52]
# s121                                                NaN
# s122                                              [s52]
# s123                                                NaN
# s124                                             [s189]
# ...                                                 ...
# s72                                          [s52, s66]
# s73                                     [s78, s37, s80]
# s74                                               [s37]
# s75                                               [s79]
# s76                                                [s0]
# s77                                           [s0, s48]
# s78                                           [s9, s73]
# s79                                               [s75]
# s8                                                  NaN
# s80                                               [s73]
# s81                                                 NaN
# s82                                  [s0, s93, s2, s96]
# s83                                  [s22, s2, s55, s3]
# s84                         [s96, s2, s15, s0, s2, s22]
# s85                            [s92, s47, s2, s15, s54]
# s86                                          [s55, s47]
# s87                                                [s3]
# s88                                                 NaN
# s89                                                 NaN
# s9                                          [s78, s176]
# s90                                               [s98]
# s91                                               [s27]
# s92                                               [s85]
# s93                                         [s82, s150]
# s94                                                 NaN
# s95                                                 NaN
# s96                                     [s84, s82, s15]
# s97                                                 NaN
# s98                                               [s90]
# s99        [s109, s107, s109, s103, s49, s111, s0, s52]
#
# [190 rows x 3 columns]

# %% [markdown]
# # Excellent! Now get sentences with most number of links

# %%
def calc_row_len(row):
    if 'list' in str(type(row['links'])):
        return len(row['links']) 
    else:
        return 0
frame_num_links = frame_art.apply(
    (lambda row: calc_row_len(row)), axis=1
)
frame_with_lengths = pd.concat([frame_art, frame_num_links], axis=1)

top_sentences = frame_with_lengths.sort_values(by=0, axis=0, ascending=False)[:11]
top_sentences.columns = ['text', 'comment', 'links', 'link length']
print top_sentences.ix[:, ['links', 'link length']]

print '\nCHUNKED SENTENCES'
for s in top_sentences['text']:
    print s[:100]

#print "These are the most linked sentences in the corpus."
#print "Sentences\n", top_sentences['text']
#print "Links they have\n", top_sentences['links']
#print "Number of links they have Links they have\n", top_sentences[0]
# Out:
#                                                   links  link length
# s0    [s66, s101, s82, s162, s118, s114, s113, s160,...           17
# s175  [s181, s178, s20, s176, s182, s180, s20, s177,...           10
# s52   [s152, s122, s150, s155, s149, s72, s146, s99,...           10
# s99        [s109, s107, s109, s103, s49, s111, s0, s52]            8
# s57                  [s49, s0, s65, s62, s62, s64, s10]            7
# s66                   [s67, s0, s69, s0, s71, s72, s71]            7
# s2                  [s84, s85, s70, s69, s82, s83, s84]            7
# s84                         [s96, s2, s15, s0, s2, s22]            6
# s119               [s131, s133, s140, s127, s126, s129]            6
# s85                            [s92, s47, s2, s15, s54]            5
# s48                         [s62, s70, s178, s127, s77]            5
#
# CHUNKED SENTENCES
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-45-f68cedd7224d> in <module>()
#      15 print '\nCHUNKED SENTENCES'
#      16 for s in top_sentences['text']:
# ---> 17     print s[:100]
#      18
#      19 #print "These are the most linked sentences in the corpus."
#
# TypeError: 'float' object has no attribute '__getitem__'
